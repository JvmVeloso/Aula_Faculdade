# %% [markdown]
# <a href="https://colab.research.google.com/github/JvmVeloso/Aula_Faculdade_Py/blob/main/Atividade_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1 - Desenha moldura. Construa uma função que desenhe um retângulo usando os caracteres ‘+’ , ‘−’ e ‘| ‘. Esta função deve receber dois parâmetros, linhas e colunas, sendo que o valor por omissão é o valor mínimo igual a 1 e o valor máximo é 20. Se valores fora da faixa forem informados, eles devem ser modificados para valores dentro da faixa de forma elegante.
# def desenhar_moldura(linhas=1, colunas=1):
#     linhas = max(min(linhas, 20), 1)
#     colunas = max(min(colunas, 20), 1)
#
#
#     print('+' + '-' * (colunas - 2) + '+')
#     for i in range(linhas - 2):
#         print('|' + ' ' * (colunas - 2) + '|')
#     print('+' + '-' * (colunas - 2) + '+')
# desenhar_moldura(8,5)

# 2 - Escreva uma função que receba uma string e uma lista. A função deve comparar a string passada
# com os elementos da lista, também passada como parâmetro. Retorne verdadeiro se a string for encontrada dentro da lista, e falso, caso contrário.
# def palavra(string):
#     lista = ["pessoa","Aviao","Moto"]
#     for texto in string:
#         if texto in lista:
#             return "Verdadeiro"
#         else:
#             return   "Falso"
#
# string = ("Carro","Moto","Aviao")
# print(palavra(string))


# 3 - Crie um programa que transfome o real em dólar
# def transformar_moeda(real = 1, dolar = 1):
#     real = float(input("Digite um valor em reais:"))
#     dolar = real * 4.94
#     return dolar
# print("O valor em dolar é:" , f"R$ {transformar_moeda():.2f}", )

# 4 - Crie um programa que calcule 25% de aumento no salário
# def aumento_de_salario(salario = 1 , aumento = 1):
#     salario = float(input("Digite seu salário:"))
#     aumento = salario * 1.25
#     return aumento
# print(aumento_de_salario())


# 5 - Crie um programa que transfome a letra Maiuscula em Minuscula

# letra = 'A'
# letra_min = letra.lower()
# print(letra_min)


# 6 - Crie um programa que verifica se a pessoa está apta ou não para votar nas eleições.
# 	Critérios:
# 		Idade menor que 16: Não pode votar
# 		16 <= Idade < 18: Opcional
# 		18 <=Idade <= 65: Obrigatório
# 		Idade maior que 65: Opcional
# def votar_eleicao(idade = 1):
#     idade = int(input("Qual a sua idade?"))
#     def pode_votar():
#         if idade < 16:
#             print("não pode votar")
#         elif 16 <= idade < 18:
#             print("Opcional")
#         elif 18 <= idade <= 65:
#             print("Obrigatório")
#         else: print("Opcional")
#     return pode_votar()
# print(votar_eleicao())


# 7 - Crie um programa que leia o seu nome completo e que apresente somente o seu primeiro e último nomes
# nome_completo = input('Digite o seu nome completo: ')
# palavras = nome_completo.split()
# primeiro_nome = palavras[0]
# ultimo_nome = palavras[-1]
# print('Primeiro nome: ', primeiro_nome)
# print('Último nome: ', ultimo_nome)


# 8 - Crie um programa que leia um número qualquer e informe se ele é par ou ímpar
# numero = float(input("Digite um número:"))
# divisor = 2
# if numero % divisor == 0:
#     print(numero, "-", "É par")
# else:
#     print(numero,"-", "é impar")

# 9 - Crie um programa que apresente o maior e o menor valores da sequência ([54, 10, 29, 87, 7, 64]

# seq = [54, 10, 29, 87, 7, 64]
# maior = seq[0]
# menor = seq[0]
# for num in seq:
#     if num > maior:
#         maior = num
#     elif num < menor:
#         menor = num
# print('Maior valor:', maior)
# print('Menor valor:', menor)
